# %% [markdown]
# # Phase 5: Episode comparison
#
# Align the GFC and recent arrears cycles on **national (CAN) troughs**, then plot each province relative to its own trough level for months 0–24.
#
# Speed rule: change in the national arrears rate from trough to trough+18 months.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path("..").resolve() / "src"))
from episodes import run_phase5
from IPython.display import Image, display

gfc_trough, recent_trough, fig, paragraph = run_phase5()
print("GFC trough:", gfc_trough.date())
print("Recent trough:", recent_trough.date())
display(Image(filename=str(fig)))
print(paragraph)
